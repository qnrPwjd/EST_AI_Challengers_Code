# %% [markdown]
# # CH02-02 연습문제 — EDA 기초와 데이터 선택·그룹 분석
#
# **총 문제 수**: 30문제 (기본 25 + 심화 5)
# **범위**: EDA 기초 / 데이터 선택 / 그룹 분석 / query() 활용 / MultiIndex
#
# | Part | 주제 | 문제 |
# |---|---|---|
# | 1 | Part 1. EDA 기초 | 문제 1~8 |
# | 2 | Part 2. 데이터 선택 | 문제 9~18 |
# | 3 | Part 3. 그룹 분석 | 문제 19~25 |
# | 4 | Part 4. ⭐ 심화: query() 활용 | 문제 26~28 |
# | 5 | Part 5. ⭐ 심화: MultiIndex | 문제 29~30 |
#
# ---

# %% [markdown]
# ---
# ## Part 1. EDA 기초

# %% [markdown]
# ### 문제 1. (초급) DataFrame 만들고 전체 구조 확인하기
#
# **문제**
# 아래 딕셔너리를 사용해 `df`를 만들고, `head()`, `shape`, `columns`를 각각 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `pd.DataFrame()`으로 표를 만듭니다.
# - `df.head()`는 앞부분 데이터를 확인합니다.
# - `df.shape`는 행과 열의 개수를 튜플로 반환합니다.
#
# </details>

# %%
import pandas as pd

data = {
    'name': ['지민', '서연', '민준', '하윤', '도윤'],
    'department': ['영업', '마케팅', '영업', '개발', '개발'],
    'sales': [120, 95, 140, 80, 110],
    'score': [85, 90, 78, 88, 92]
}

# DataFrame을 생성하세요.
df = 

# 앞부분 데이터를 출력하세요.


# 행과 열 개수를 출력하세요.


# 컬럼명을 출력하세요.

# %% [markdown]
# ### 문제 2. (초급) tail()과 sample()로 데이터 살펴보기
#
# **문제**
# 주어진 DataFrame에서 마지막 3개 행을 출력하고, 무작위 2개 행을 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 마지막 행은 `tail()`로 확인합니다.
# - 무작위 행은 `sample()`로 확인합니다.
# - 개수는 괄호 안에 숫자로 지정합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'product': ['노트북', '마우스', '키보드', '모니터', '프린터', '태블릿'],
    'price': [1200000, 25000, 70000, 300000, 180000, 650000],
    'stock': [5, 30, 15, 8, 4, 10]
})

# 마지막 3개 행을 출력하세요.


# 무작위 2개 행을 출력하세요.

# %% [markdown]
# ### 문제 3. (초급) info()로 결측치와 자료형 확인하기
#
# **문제**
# 주어진 DataFrame의 기본 정보를 `info()`로 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `info()`는 컬럼별 non-null 개수와 dtype을 보여줍니다.
# - 출력 결과에서 결측치가 있는 컬럼을 확인할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'age': [24, 31, None, 28],
    'city': ['서울', '부산', '제주', None],
    'purchase': [3, 5, 2, 7]
})

# DataFrame의 기본 정보를 확인하세요.

# %% [markdown]
# ### 문제 4. (초급) describe()로 기초 통계량 확인하기
#
# **문제**
# 주어진 DataFrame에서 숫자형 컬럼의 기초 통계량을 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `describe()`를 사용합니다.
# - 평균, 표준편차, 최솟값, 최댓값 등을 확인할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'math': [80, 90, 75, 60, 95],
    'english': [70, 85, 90, 65, 100],
    'science': [88, 92, 79, 85, 91]
})

# 기초 통계량을 확인하세요.

# %% [markdown]
# ### 문제 5. (초급) isna()와 sum()으로 결측치 개수 확인하기
#
# **문제**
# 컬럼별 결측치 개수를 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 결측 여부는 `isna()`로 확인합니다.
# - 컬럼별 개수는 뒤에 `sum()`을 붙입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E'],
    'age': [20, None, 25, 30, None],
    'score': [80, 90, None, 70, 85]
})

# 컬럼별 결측치 개수를 출력하세요.

# %% [markdown]
# ### 문제 6. (초급) value_counts()로 빈도 확인하기
#
# **문제**
# 고객 등급별 인원 수를 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 범주형 컬럼의 빈도는 `value_counts()`로 확인합니다.
# - `df['컬럼명']` 형태로 Series를 선택한 뒤 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'customer': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'grade': ['VIP', 'Basic', 'VIP', 'Gold', 'Basic', 'VIP', 'Gold']
})

# grade별 개수를 출력하세요.

# %% [markdown]
# ### 문제 7. (중급) unique()와 nunique() 사용하기
#
# **문제**
# `city` 컬럼의 고유값 목록과 고유값 개수를 각각 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 고유값 목록은 `unique()`입니다.
# - 고유값 개수는 `nunique()`입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E', 'F'],
    'city': ['서울', '부산', '서울', '제주', '부산', '서울']
})

# city의 고유값 목록을 출력하세요.


# city의 고유값 개수를 출력하세요.

# %% [markdown]
# ### 문제 8. (중급) 숫자형과 문자형 컬럼 구분하기
#
# **문제**
# `select_dtypes()`를 사용해 숫자형 컬럼만 선택해 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `select_dtypes()`를 사용합니다.
# - 숫자형 컬럼은 `include='number'`로 선택할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C'],
    'age': [20, 25, 30],
    'score': [80.5, 90.0, 77.5],
    'city': ['서울', '부산', '제주']
})

# 숫자형 컬럼만 선택하세요.

# %% [markdown]
# ---
# ## Part 2. 데이터 선택

# %% [markdown]
# ### 문제 9. (초급) 하나의 컬럼 선택하기
#
# **문제**
# `name` 컬럼만 선택해 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 하나의 컬럼은 `df['컬럼명']`으로 선택합니다.
# - 결과는 Series 형태입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['지민', '서연', '민준'],
    'age': [24, 31, 28],
    'score': [85, 90, 78]
})

# name 컬럼만 선택하세요.

# %% [markdown]
# ### 문제 10. (초급) 여러 컬럼 선택하기
#
# **문제**
# `name`과 `score` 컬럼만 선택해 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 여러 컬럼은 리스트로 묶어서 선택합니다.
# - 형태는 `df[['컬럼1', '컬럼2']]`입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['지민', '서연', '민준'],
    'age': [24, 31, 28],
    'score': [85, 90, 78]
})

# name과 score 컬럼만 선택하세요.

# %% [markdown]
# ### 문제 11. (초급) 조건으로 행 선택하기
#
# **문제**
# `score`가 80 이상인 학생만 선택해 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 조건식은 `df['score'] >= 80`처럼 만듭니다.
# - 조건식을 다시 `df[조건식]` 안에 넣습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['지민', '서연', '민준', '하윤'],
    'score': [85, 72, 90, 65]
})

# score가 80 이상인 행만 선택하세요.

# %% [markdown]
# ### 문제 12. (중급) 여러 조건으로 행 선택하기
#
# **문제**
# `department`가 '영업'이고 `sales`가 100 이상인 행만 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 조건이 2개 이상이면 각각 괄호로 묶습니다.
# - AND 조건은 `&`를 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'department': ['영업', '개발', '영업', '영업'],
    'sales': [120, 80, 90, 150]
})

# department가 영업이고 sales가 100 이상인 행을 선택하세요.

# %% [markdown]
# ### 문제 13. (중급) OR 조건으로 행 선택하기
#
# **문제**
# `city`가 '서울'이거나 `grade`가 'VIP'인 행을 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - OR 조건은 `|`를 사용합니다.
# - 각 조건은 괄호로 묶습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E'],
    'city': ['서울', '부산', '제주', '서울', '대구'],
    'grade': ['Basic', 'VIP', 'Basic', 'Gold', 'VIP']
})

# city가 서울이거나 grade가 VIP인 행을 선택하세요.

# %% [markdown]
# ### 문제 14. (중급) isin()으로 여러 값 포함 여부 확인하기
#
# **문제**
# `city`가 '서울' 또는 '부산'인 행만 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 여러 값 중 포함 여부는 `isin()`을 사용합니다.
# - `df['city'].isin(['서울', '부산'])` 형태입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E'],
    'city': ['서울', '부산', '제주', '대구', '서울'],
    'amount': [100, 200, 150, 120, 180]
})

# city가 서울 또는 부산인 행을 선택하세요.

# %% [markdown]
# ### 문제 15. (중급) between()으로 범위 조건 선택하기
#
# **문제**
# `age`가 25 이상 35 이하인 행만 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 범위 조건은 `between()`을 사용할 수 있습니다.
# - `df['age'].between(25, 35)` 형태입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E'],
    'age': [22, 25, 31, 36, 29]
})

# age가 25 이상 35 이하인 행을 선택하세요.

# %% [markdown]
# ### 문제 16. (중급) loc로 행과 열 선택하기
#
# **문제**
# `name`이 '서연'인 행의 `score` 값을 `loc`로 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `loc[행조건, 열이름]` 형태를 사용합니다.
# - 조건은 `df['name'] == '서연'`입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['지민', '서연', '민준'],
    'score': [85, 90, 78],
    'grade': ['B', 'A', 'C']
})

# 서연의 score를 loc로 선택하세요.

# %% [markdown]
# ### 문제 17. (중급) iloc로 위치 기반 선택하기
#
# **문제**
# 두 번째 행부터 네 번째 행까지, 첫 번째 컬럼과 두 번째 컬럼을 `iloc`로 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `iloc`는 위치 번호 기반입니다.
# - 파이썬 슬라이싱처럼 끝 번호는 포함되지 않습니다.
# - 두 번째 행부터 네 번째 행까지는 `1:4`입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D', 'E'],
    'age': [20, 21, 22, 23, 24],
    'score': [80, 85, 90, 70, 75]
})

# 두 번째~네 번째 행, 첫 번째~두 번째 컬럼을 선택하세요.

# %% [markdown]
# ### 문제 18. (중급) sort_values()와 reset_index() 사용하기
#
# **문제**
# `sales`를 기준으로 내림차순 정렬한 뒤 인덱스를 초기화하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 정렬은 `sort_values()`를 사용합니다.
# - 내림차순은 `ascending=False`입니다.
# - 인덱스 초기화는 `reset_index(drop=True)`입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'sales': [120, 80, 200, 150]
})

# sales 기준 내림차순 정렬 후 인덱스를 초기화하세요.

# %% [markdown]
# ---
# ## Part 3. 그룹 분석

# %% [markdown]
# ### 문제 19. (초급) groupby()로 부서별 평균 구하기
#
# **문제**
# 부서별 `sales` 평균을 구하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 그룹 기준은 `department`입니다.
# - 평균은 `mean()`입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'department': ['영업', '개발', '영업', '개발', '마케팅'],
    'sales': [120, 80, 150, 100, 90]
})

# 부서별 sales 평균을 구하세요.

# %% [markdown]
# ### 문제 20. (초급) 그룹별 합계 구하기
#
# **문제**
# 지역별 `amount` 합계를 구하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 지역 기준으로 그룹화합니다.
# - 합계는 `sum()`을 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'region': ['서울', '부산', '서울', '제주', '부산'],
    'amount': [100, 200, 150, 120, 80]
})

# 지역별 amount 합계를 구하세요.

# %% [markdown]
# ### 문제 21. (중급) 그룹별 개수 세기
#
# **문제**
# 도시별 고객 수를 구하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 도시별로 그룹화합니다.
# - 고객 수는 `count()` 또는 `size()`로 구할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'customer': ['A', 'B', 'C', 'D', 'E', 'F'],
    'city': ['서울', '부산', '서울', '제주', '부산', '서울']
})

# 도시별 고객 수를 구하세요.

# %% [markdown]
# ### 문제 22. (중급) agg()로 여러 통계량 한 번에 구하기
#
# **문제**
# 부서별 `sales`의 평균, 최댓값, 최솟값을 한 번에 구하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 여러 통계량은 `agg()`를 사용합니다.
# - `agg(['mean', 'max', 'min'])` 형태로 작성할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'department': ['영업', '개발', '영업', '개발', '마케팅', '영업'],
    'sales': [120, 80, 150, 100, 90, 200]
})

# 부서별 sales의 평균, 최댓값, 최솟값을 구하세요.

# %% [markdown]
# ### 문제 23. (중급) 두 개의 기준으로 그룹화하기
#
# **문제**
# `region`과 `category`별 `amount` 합계를 구하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 그룹 기준이 2개면 리스트로 전달합니다.
# - `groupby(['region', 'category'])` 형태입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'region': ['서울', '서울', '부산', '부산', '서울', '제주'],
    'category': ['식품', '전자', '식품', '전자', '식품', '전자'],
    'amount': [100, 300, 150, 250, 120, 200]
})

# region과 category별 amount 합계를 구하세요.

# %% [markdown]
# ### 문제 24. (중급) 그룹 결과를 DataFrame으로 정리하기
#
# **문제**
# 부서별 평균 점수를 구한 뒤, 인덱스를 초기화하여 DataFrame으로 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `groupby()` 결과 뒤에 `reset_index()`를 붙입니다.
# - 결과를 표 형태로 보기 좋게 정리할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'department': ['A', 'A', 'B', 'B', 'C'],
    'score': [80, 90, 70, 85, 95]
})

# 부서별 평균 점수를 구하고 인덱스를 초기화하세요.

# %% [markdown]
# ### 문제 25. (중급) 상위 그룹 찾기
#
# **문제**
# 상품 카테고리별 매출 합계를 구하고, 매출 합계가 큰 순서로 정렬하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 먼저 `groupby()`로 카테고리별 합계를 구합니다.
# - 그다음 `sort_values(ascending=False)`를 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'category': ['식품', '전자', '식품', '생활', '전자', '생활'],
    'sales': [100, 500, 150, 80, 300, 120]
})

# 카테고리별 매출 합계를 큰 순서로 정렬하세요.

# %% [markdown]
# ---
# ## Part 4. ⭐ 심화: query() 활용

# %% [markdown]
# ### 문제 26. (심화) query()로 조건 검색하기
#
# **문제**
# `query()`를 사용해 `score`가 80 이상인 행을 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `df.query('조건식')` 형태를 사용합니다.
# - 문자열 안에 조건식을 작성합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'score': [75, 82, 91, 68]
})

# query()를 사용해 score가 80 이상인 행을 선택하세요.

# %% [markdown]
# ### 문제 27. (심화) query()에서 문자열 조건 사용하기
#
# **문제**
# `department`가 '영업'인 행만 `query()`로 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 문자열 값을 비교할 때는 조건식 안에서 따옴표를 사용합니다.
# - 예: `df.query("col == '값'")`
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'department': ['영업', '개발', '영업', '마케팅'],
    'sales': [120, 80, 150, 90]
})

# department가 영업인 행을 query()로 선택하세요.

# %% [markdown]
# ### 문제 28. (심화) query()에서 외부 변수 사용하기
#
# **문제**
# 외부 변수 `min_sales`를 사용해 `sales`가 `min_sales` 이상인 행을 `query()`로 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - `query()` 안에서 외부 변수는 `@변수명`으로 사용합니다.
# - 예: `df.query('sales >= @min_sales')`
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'sales': [100, 200, 150, 80]
})

min_sales = 150

# min_sales 이상인 행을 query()로 선택하세요.

# %% [markdown]
# ---
# ## Part 5. ⭐ 심화: MultiIndex

# %% [markdown]
# ### 문제 29. (심화) MultiIndex 결과 만들기
#
# **문제**
# `region`과 `category`를 기준으로 그룹화하여 `sales` 합계를 구하고, 결과의 인덱스를 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 두 개 이상의 기준으로 groupby하면 MultiIndex가 만들어집니다.
# - 결과의 인덱스는 `.index`로 확인합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'region': ['서울', '서울', '부산', '부산', '제주'],
    'category': ['식품', '전자', '식품', '전자', '식품'],
    'sales': [100, 300, 150, 250, 120]
})

# region과 category별 sales 합계를 구하세요.
result = 

# 결과를 출력하세요.


# 결과의 index를 출력하세요.

# %% [markdown]
# ### 문제 30. (심화) unstack()으로 MultiIndex를 표 형태로 바꾸기
#
# **문제**
# `region`과 `category`별 `sales` 합계를 구한 뒤, `unstack()`으로 카테고리를 컬럼 형태로 바꾸세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 먼저 두 기준으로 그룹화합니다.
# - MultiIndex 결과 뒤에 `unstack()`을 붙이면 계층 인덱스 일부가 컬럼으로 이동합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'region': ['서울', '서울', '부산', '부산', '제주', '제주'],
    'category': ['식품', '전자', '식품', '전자', '식품', '전자'],
    'sales': [100, 300, 150, 250, 120, 180]
})

# region과 category별 sales 합계를 구하고 unstack()으로 변환하세요.
