# %% [markdown]
# # CH10 인코딩_스케일링_데이터수집 연습문제
#
# ## 안내
# - 각 문제를 읽고 코드셀에 직접 코드를 작성하세요.
# - 힌트는 접혀 있습니다. 필요할 때만 펼쳐서 확인하세요.
# - 문제는 기본 → 응용 → 심화 순서로 구성되어 있습니다.

# %% [markdown]
# ## 인코딩

# %% [markdown]
# ### 문제 1. LabelEncoder로 범주형 데이터 변환하기 ⭐
#
# fruit 컬럼의 문자열 값을 LabelEncoder를 사용하여 숫자로 변환하세요.
#
# **요구사항**
# - LabelEncoder를 import 하세요.
# - fruit_encoded 컬럼을 새로 만드세요.
# - 변환 결과를 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - sklearn.preprocessing에서 LabelEncoder를 불러옵니다.
# - fit_transform()을 사용하면 학습과 변환을 한 번에 수행할 수 있습니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df = pd.DataFrame({
    'fruit': ['apple', 'banana', 'apple', 'orange', 'banana']
})

# LabelEncoder 객체를 생성하세요.
encoder = 

# fruit 컬럼을 숫자로 변환하여 fruit_encoded 컬럼을 만드세요.
df['fruit_encoded'] = 

# 결과를 출력하세요.
df

# %% [markdown]
# ### 문제 2. LabelEncoder의 classes_ 확인하기 ⭐
#
# LabelEncoder로 변환한 뒤, 어떤 범주가 어떤 순서로 학습되었는지 classes_로 확인하세요.
#
# **요구사항**
# - LabelEncoder를 사용하세요.
# - classes_ 속성을 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - encoder.classes_를 출력하면 학습된 범주 목록을 확인할 수 있습니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df = pd.DataFrame({
    'grade': ['B', 'A', 'C', 'A', 'B']
})

# LabelEncoder 객체를 생성하세요.
encoder = 

# grade 컬럼을 변환하세요.
encoded = 

# encoder가 학습한 범주 목록을 출력하세요.

# %% [markdown]
# ### 문제 3. pd.get_dummies로 원-핫 인코딩하기 ⭐
#
# city 컬럼을 pd.get_dummies()로 원-핫 인코딩하세요.
#
# **요구사항**
# - pd.get_dummies()를 사용하세요.
# - 결과를 encoded_df 변수에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - pd.get_dummies(df, columns=['city']) 형태로 작성할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park'],
    'city': ['Seoul', 'Busan', 'Jeju']
})

# city 컬럼을 원-핫 인코딩하세요.
encoded_df = 

# 결과를 출력하세요.
encoded_df

# %% [markdown]
# ### 문제 4. drop_first 옵션 사용하기 ⭐⭐
#
# gender 컬럼을 원-핫 인코딩하되, drop_first=True를 사용하여 첫 번째 범주를 제거하세요.
#
# **요구사항**
# - pd.get_dummies()를 사용하세요.
# - drop_first=True를 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - drop_first=True는 기준 범주 하나를 제거합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'gender': ['M', 'F', 'F', 'M']
})

# 첫 번째 범주를 제거하며 원-핫 인코딩하세요.
encoded_df = 

# 결과를 출력하세요.
encoded_df

# %% [markdown]
# ### 문제 5. OneHotEncoder 사용하기 ⭐⭐
#
# sklearn의 OneHotEncoder를 사용하여 color 컬럼을 인코딩하세요.
#
# **요구사항**
# - OneHotEncoder를 import 하세요.
# - sparse_output=False를 설정하세요.
# - 결과를 DataFrame으로 변환하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - OneHotEncoder는 2차원 입력을 기대하므로 df[['color']] 형태로 넣습니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

df = pd.DataFrame({
    'color': ['red', 'blue', 'green', 'red']
})

# OneHotEncoder 객체를 생성하세요.
encoder = 

# color 컬럼을 인코딩하세요.
encoded = 

# 인코딩 결과를 DataFrame으로 변환하세요.
encoded_df = 

# 결과를 출력하세요.
encoded_df

# %% [markdown]
# ### 문제 6. handle_unknown 옵션 이해하기 ⭐⭐⭐
#
# 학습 데이터에 없던 새로운 범주가 들어와도 에러가 나지 않도록 OneHotEncoder를 설정하세요.
#
# **요구사항**
# - handle_unknown='ignore'를 사용하세요.
# - train 데이터로 fit 하세요.
# - test 데이터를 transform 하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 훈련 데이터에는 없는 'green'이 테스트 데이터에 포함되어 있습니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

train = pd.DataFrame({'color': ['red', 'blue', 'red']})
test = pd.DataFrame({'color': ['red', 'green']})

# 새로운 범주가 들어와도 에러가 나지 않도록 인코더를 생성하세요.
encoder = 

# train 데이터로 학습하세요.
encoder.

# test 데이터를 변환하세요.
test_encoded = 

# 결과를 출력하세요.
test_encoded

# %% [markdown]
# ## 스케일링

# %% [markdown]
# ### 문제 7. StandardScaler로 표준화하기 ⭐
#
# height와 weight 컬럼을 StandardScaler로 표준화하세요.
#
# **요구사항**
# - StandardScaler를 import 하세요.
# - fit_transform()을 사용하세요.
# - 결과를 scaled_df로 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - StandardScaler는 평균 0, 표준편차 1에 가깝게 변환합니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.DataFrame({
    'height': [160, 170, 180],
    'weight': [55, 70, 85]
})

# StandardScaler 객체를 생성하세요.
scaler = 

# height, weight 컬럼을 표준화하세요.
scaled = 

# 결과를 DataFrame으로 변환하세요.
scaled_df = 

# 결과를 출력하세요.
scaled_df

# %% [markdown]
# ### 문제 8. MinMaxScaler로 정규화하기 ⭐
#
# score 컬럼을 0~1 범위로 정규화하세요.
#
# **요구사항**
# - MinMaxScaler를 import 하세요.
# - fit_transform()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - MinMaxScaler는 최솟값을 0, 최댓값을 1로 변환합니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

df = pd.DataFrame({
    'score': [60, 70, 80, 90, 100]
})

# MinMaxScaler 객체를 생성하세요.
scaler = 

# score 컬럼을 정규화하세요.
df['score_scaled'] = 

# 결과를 출력하세요.
df

# %% [markdown]
# ### 문제 9. RobustScaler 사용하기 ⭐⭐
#
# income 컬럼을 RobustScaler로 변환하세요.
#
# **요구사항**
# - RobustScaler를 import 하세요.
# - fit_transform()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - RobustScaler는 중앙값과 IQR을 기준으로 변환합니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import RobustScaler

df = pd.DataFrame({
    'income': [2000, 2200, 2500, 2700, 10000]
})

# RobustScaler 객체를 생성하세요.
scaler = 

# income 컬럼을 변환하세요.
df['income_scaled'] = 

# 결과를 출력하세요.
df

# %% [markdown]
# ### 문제 10. fit과 transform 분리하기 ⭐⭐⭐
#
# train 데이터로 StandardScaler를 학습하고, train과 test를 각각 변환하세요.
#
# **요구사항**
# - train 데이터에 fit()을 적용하세요.
# - train과 test에는 transform()을 적용하세요.
# - fit_transform을 test에 사용하지 마세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 스케일러는 train 기준으로만 학습해야 합니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

train = pd.DataFrame({'score': [60, 70, 80, 90]})
test = pd.DataFrame({'score': [75, 85]})

# StandardScaler 객체를 생성하세요.
scaler = 

# train 데이터로 scaler를 학습하세요.
scaler.

# train 데이터를 변환하세요.
train_scaled = 

# test 데이터를 변환하세요.
test_scaled = 

# 결과를 출력하세요.
train_scaled, test_scaled

# %% [markdown]
# ### 문제 11. 여러 수치형 컬럼만 선택해 스케일링하기 ⭐⭐
#
# age와 income 컬럼만 선택하여 StandardScaler로 변환하세요.
#
# **요구사항**
# - 수치형 컬럼 리스트를 만드세요.
# - 해당 컬럼만 스케일링하세요.
# - 원본 df에 결과를 반영하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - numeric_cols = ['age', 'income']처럼 컬럼 리스트를 만들 수 있습니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park'],
    'age': [25, 30, 35],
    'income': [3000, 4000, 5000]
})

# 스케일링할 수치형 컬럼 리스트를 만드세요.
numeric_cols = 

# StandardScaler 객체를 생성하세요.
scaler = 

# 선택한 컬럼만 스케일링하여 원본 df에 반영하세요.
df[numeric_cols] = 

# 결과를 출력하세요.
df

# %% [markdown]
# ## 웹크롤링

# %% [markdown]
# ### 문제 12. requests로 웹페이지 요청하기 ⭐
#
# requests.get()을 사용하여 예시 URL에 요청을 보내고 상태코드를 확인하세요.
#
# **요구사항**
# - requests를 import 하세요.
# - requests.get()을 사용하세요.
# - status_code를 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 응답 객체의 status_code 속성을 확인합니다.
#
# </details>

# %%
import requests

url = 'https://example.com'

# url에 GET 요청을 보내세요.
response = 

# 상태코드를 출력하세요.

# %% [markdown]
# ### 문제 13. BeautifulSoup 객체 만들기 ⭐
#
# HTML 문자열을 BeautifulSoup 객체로 변환하세요.
#
# **요구사항**
# - BeautifulSoup을 import 하세요.
# - html.parser를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - BeautifulSoup(html, 'html.parser') 형태로 작성합니다.
#
# </details>

# %%
from bs4 import BeautifulSoup

html = '''
<html>
<body>
    <h1>뉴스 제목</h1>
    <p>본문 내용입니다.</p>
</body>
</html>
'''

# BeautifulSoup 객체를 생성하세요.
soup = 

# soup 객체를 출력하세요.
soup

# %% [markdown]
# ### 문제 14. find로 하나의 태그 찾기 ⭐
#
# BeautifulSoup에서 첫 번째 h1 태그의 텍스트를 추출하세요.
#
# **요구사항**
# - find()를 사용하세요.
# - get_text()를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - soup.find('h1').get_text() 형태로 작성합니다.
#
# </details>

# %%
from bs4 import BeautifulSoup

html = '''
<html>
<body>
    <h1>첫 번째 제목</h1>
    <h1>두 번째 제목</h1>
</body>
</html>
'''

soup = BeautifulSoup(html, 'html.parser')

# 첫 번째 h1 태그를 찾으세요.
title_tag = 

# h1 태그의 텍스트를 추출하세요.
title_text = 

# 결과를 출력하세요.
title_text

# %% [markdown]
# ### 문제 15. find_all로 여러 태그 찾기 ⭐⭐
#
# 모든 li 태그의 텍스트를 리스트로 추출하세요.
#
# **요구사항**
# - find_all()을 사용하세요.
# - 반복문 또는 리스트 컴프리헨션을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - find_all()은 태그 목록을 리스트 형태로 반환합니다.
#
# </details>

# %%
from bs4 import BeautifulSoup

html = '''
<ul>
    <li>Python</li>
    <li>Pandas</li>
    <li>Machine Learning</li>
</ul>
'''

soup = BeautifulSoup(html, 'html.parser')

# 모든 li 태그를 찾으세요.
items = 

# 각 li 태그의 텍스트를 리스트로 추출하세요.
texts = 

# 결과를 출력하세요.
texts

# %% [markdown]
# ### 문제 16. select_one으로 CSS 선택자 사용하기 ⭐⭐
#
# CSS 선택자를 사용하여 class가 title인 태그의 텍스트를 추출하세요.
#
# **요구사항**
# - select_one()을 사용하세요.
# - '.title' 선택자를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - CSS에서 클래스 선택자는 점(.)을 사용합니다.
#
# </details>

# %%
from bs4 import BeautifulSoup

html = '''
<div>
    <p class="title">오늘의 기사</p>
    <p class="content">기사 본문입니다.</p>
</div>
'''

soup = BeautifulSoup(html, 'html.parser')

# class가 title인 태그를 선택하세요.
title_tag = 

# 텍스트를 추출하세요.
title_text = 

# 결과를 출력하세요.
title_text

# %% [markdown]
# ### 문제 17. select로 여러 요소 선택하기 ⭐⭐
#
# class가 item인 모든 태그의 텍스트를 리스트로 추출하세요.
#
# **요구사항**
# - select()를 사용하세요.
# - '.item' 선택자를 사용하세요.
# - 리스트 컴프리헨션을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - select()는 조건에 맞는 요소들을 리스트로 반환합니다.
#
# </details>

# %%
from bs4 import BeautifulSoup

html = '''
<div>
    <span class="item">A상품</span>
    <span class="item">B상품</span>
    <span class="item">C상품</span>
</div>
'''

soup = BeautifulSoup(html, 'html.parser')

# class가 item인 모든 태그를 선택하세요.
items = 

# 각 태그의 텍스트를 리스트로 추출하세요.
item_names = 

# 결과를 출력하세요.
item_names

# %% [markdown]
# ## OpenAPI

# %% [markdown]
# ### 문제 18. params로 API 요청 파라미터 전달하기 ⭐⭐
#
# requests.get()의 params 옵션을 사용하여 API 요청 파라미터를 전달하세요.
#
# **요구사항**
# - params 딕셔너리를 만드세요.
# - requests.get(url, params=params)를 사용하세요.
# - 요청 URL을 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - response.url을 출력하면 실제 요청 URL을 확인할 수 있습니다.
#
# </details>

# %%
import requests

url = 'https://httpbin.org/get'

# 요청 파라미터를 딕셔너리로 만드세요.
params = {
    'query': ,
    'page': 
}

# params를 포함하여 GET 요청을 보내세요.
response = 

# 실제 요청 URL을 출력하세요.

# %% [markdown]
# ### 문제 19. JSON 응답을 딕셔너리로 변환하기 ⭐⭐
#
# API 응답 객체에서 json() 메서드를 사용하여 JSON 데이터를 딕셔너리로 변환하세요.
#
# **요구사항**
# - requests.get()을 사용하세요.
# - response.json()을 사용하세요.
# - 결과의 타입을 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - response.json()은 JSON 응답을 Python dict로 변환합니다.
#
# </details>

# %%
import requests

url = 'https://httpbin.org/get'
params = {'query': 'data'}

# GET 요청을 보내세요.
response = 

# JSON 응답을 Python 객체로 변환하세요.
data = 

# data의 타입을 확인하세요.

# %% [markdown]
# ### 문제 20. API 응답에서 특정 값 추출하기 ⭐⭐
#
# httpbin 응답 데이터에서 args 안의 query 값을 추출하세요.
#
# **요구사항**
# - response.json()을 사용하세요.
# - 딕셔너리 인덱싱으로 data['args']['query'] 값을 추출하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 중첩 딕셔너리는 data['상위키']['하위키'] 형태로 접근합니다.
#
# </details>

# %%
import requests

url = 'https://httpbin.org/get'
params = {'query': 'python'}

response = requests.get(url, params=params)
data = response.json()

# args 안의 query 값을 추출하세요.
query_value = 

# 결과를 출력하세요.
query_value

# %% [markdown]
# ## JSON 활용

# %% [markdown]
# ### 문제 21. json.dumps로 딕셔너리를 JSON 문자열로 변환하기 ⭐
#
# Python 딕셔너리를 JSON 문자열로 변환하세요.
#
# **요구사항**
# - json 모듈을 import 하세요.
# - json.dumps()를 사용하세요.
# - ensure_ascii=False를 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 한글이 깨지지 않게 하려면 ensure_ascii=False를 사용합니다.
#
# </details>

# %%
import json

data = {
    'name': '홍길동',
    'age': 30,
    'city': '제주'
}

# 딕셔너리를 JSON 문자열로 변환하세요.
json_text = 

# 결과를 출력하세요.
json_text

# %% [markdown]
# ### 문제 22. json.loads로 JSON 문자열을 딕셔너리로 변환하기 ⭐
#
# JSON 문자열을 Python 딕셔너리로 변환하세요.
#
# **요구사항**
# - json.loads()를 사용하세요.
# - 변환 결과의 name 값을 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - loads의 s는 string을 의미한다고 이해하면 쉽습니다.
#
# </details>

# %%
import json

json_text = '{"name": "Kim", "age": 25, "city": "Seoul"}'

# JSON 문자열을 딕셔너리로 변환하세요.
data = 

# name 값을 추출하세요.
name = 

# 결과를 출력하세요.
name

# %% [markdown]
# ### 문제 23. 중첩 JSON에서 리스트 데이터 추출하기 ⭐⭐
#
# JSON 형태의 딕셔너리에서 items 리스트를 꺼내 DataFrame으로 변환하세요.
#
# **요구사항**
# - items 값을 추출하세요.
# - pd.DataFrame()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - data['response']['items'] 순서로 접근합니다.
#
# </details>

# %%
import pandas as pd

data = {
    'response': {
        'items': [
            {'name': 'A상품', 'price': 1000},
            {'name': 'B상품', 'price': 2000}
        ]
    }
}

# items 리스트를 추출하세요.
items = 

# items를 DataFrame으로 변환하세요.
df = 

# 결과를 출력하세요.
df

# %% [markdown]
# ### 문제 24. json_normalize로 중첩 데이터 펼치기 ⭐⭐⭐
#
# pd.json_normalize()를 사용하여 중첩된 user 정보를 평평한 DataFrame으로 변환하세요.
#
# **요구사항**
# - pd.json_normalize()를 사용하세요.
# - user.name, user.city 형태의 컬럼이 나오도록 하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 리스트 안에 중첩 딕셔너리가 있을 때 json_normalize가 유용합니다.
#
# </details>

# %%
import pandas as pd

data = [
    {'id': 1, 'user': {'name': 'Kim', 'city': 'Seoul'}},
    {'id': 2, 'user': {'name': 'Lee', 'city': 'Busan'}}
]

# 중첩 JSON을 DataFrame으로 펼치세요.
df = 

# 결과를 출력하세요.
df

# %% [markdown]
# ## robots / 크롤링 윤리

# %% [markdown]
# ### 문제 25. robots.txt URL 만들기 ⭐
#
# 사이트 주소를 바탕으로 robots.txt 주소를 만드세요.
#
# **요구사항**
# - base_url 변수를 사용하세요.
# - robots_url 변수를 만드세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 일반적으로 사이트 루트 뒤에 /robots.txt를 붙입니다.
#
# </details>

# %%
base_url = 'https://example.com'

# robots.txt 주소를 만드세요.
robots_url = 

# 결과를 출력하세요.
robots_url

# %% [markdown]
# ### 문제 26. User-Agent 헤더 설정하기 ⭐⭐
#
# requests 요청 시 User-Agent 헤더를 포함하세요.
#
# **요구사항**
# - headers 딕셔너리를 만드세요.
# - requests.get()에 headers를 전달하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - headers={'User-Agent': '...'} 형태로 작성합니다.
#
# </details>

# %%
import requests

url = 'https://example.com'

# User-Agent 헤더를 만드세요.
headers = {
    'User-Agent': 
}

# headers를 포함하여 요청을 보내세요.
response = 

# 상태코드를 출력하세요.
response.status_code

# %% [markdown]
# ### 문제 27. 요청 간격 설정하기 ⭐
#
# 반복 요청 사이에 1초 대기하도록 코드를 작성하세요.
#
# **요구사항**
# - time 모듈을 import 하세요.
# - time.sleep(1)을 사용하세요.
# - 반복문 안에서 대기하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - sleep은 서버에 부담을 줄이기 위해 사용합니다.
#
# </details>

# %%
import time

urls = ['url1', 'url2', 'url3']

for url in urls:
    print(url)
    # 1초 대기하세요.

# %% [markdown]
# ## 종합문제

# %% [markdown]
# ### 문제 28. 인코딩과 스케일링 종합 전처리 ⭐⭐⭐
#
# city는 원-핫 인코딩하고, age와 income은 StandardScaler로 변환하세요.
#
# **요구사항**
# - pd.get_dummies()를 사용하세요.
# - StandardScaler를 사용하세요.
# - 수치형 컬럼만 스케일링하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 먼저 수치형 컬럼을 스케일링한 뒤 get_dummies를 적용하거나, 반대로 해도 됩니다.
#
# </details>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.DataFrame({
    'city': ['Seoul', 'Busan', 'Jeju'],
    'age': [25, 30, 35],
    'income': [3000, 4000, 5000]
})

# 스케일링할 수치형 컬럼을 지정하세요.
numeric_cols = 

# StandardScaler 객체를 생성하세요.
scaler = 

# 수치형 컬럼을 스케일링하세요.
df[numeric_cols] = 

# city 컬럼을 원-핫 인코딩하세요.
encoded_df = 

# 결과를 출력하세요.
encoded_df

# %% [markdown]
# ### 문제 29. HTML 상품 목록을 DataFrame으로 만들기 ⭐⭐⭐
#
# HTML에서 상품명과 가격을 추출하여 DataFrame으로 만드세요.
#
# **요구사항**
# - BeautifulSoup을 사용하세요.
# - select()를 사용하세요.
# - 상품명과 가격 리스트를 만드세요.
# - DataFrame으로 변환하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 상품명은 .name, 가격은 .price 선택자를 사용할 수 있습니다.
#
# </details>

# %%
from bs4 import BeautifulSoup
import pandas as pd

html = '''
<div class="product">
    <span class="name">A상품</span>
    <span class="price">1000</span>
</div>
<div class="product">
    <span class="name">B상품</span>
    <span class="price">2000</span>
</div>
'''

soup = BeautifulSoup(html, 'html.parser')

# 상품명 태그들을 선택하세요.
name_tags = 

# 가격 태그들을 선택하세요.
price_tags = 

# 상품명 리스트를 만드세요.
names = 

# 가격 리스트를 정수형으로 만드세요.
prices = 

# DataFrame을 생성하세요.
df = 

# 결과를 출력하세요.
df

# %% [markdown]
# ## 심화: Selenium / 정규표현식 / XML

# %% [markdown]
# ### 문제 30. Selenium WebDriver 기본 구조 작성하기 ⭐⭐⭐
#
# Selenium으로 Chrome 브라우저를 실행하고 특정 URL에 접속하는 기본 코드를 작성하세요.
#
# **요구사항**
# - webdriver를 import 하세요.
# - Chrome 드라이버 객체를 생성하세요.
# - get()으로 URL에 접속하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 실행 환경에 따라 ChromeDriver 설치가 필요할 수 있습니다.
#
# </details>

# %%
# 실행 환경에 따라 selenium 설치 및 드라이버 설정이 필요합니다.
from selenium import webdriver

url = 'https://example.com'

# Chrome 브라우저 객체를 생성하세요.
driver = 

# url에 접속하세요.
driver.

# 페이지 제목을 출력하세요.


# 브라우저를 종료하세요.
driver.

# %% [markdown]
# ### 문제 31. 정규표현식으로 숫자만 추출하기 ⭐⭐
#
# 문자열에서 숫자만 추출하세요.
#
# **요구사항**
# - re 모듈을 import 하세요.
# - re.findall()을 사용하세요.
# - 숫자 패턴 r'\d+'를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - \d는 숫자, +는 하나 이상 반복을 의미합니다.
#
# </details>

# %%
import re

text = '상품 가격은 12,000원이고 배송비는 3,000원입니다.'

# 숫자 패턴을 작성하세요.
pattern = 

# 숫자만 추출하세요.
numbers = 

# 결과를 출력하세요.
numbers

# %% [markdown]
# ### 문제 32. 정규표현식으로 이메일 추출하기 ⭐⭐⭐
#
# 문자열에서 이메일 주소를 추출하세요.
#
# **요구사항**
# - re.findall()을 사용하세요.
# - 이메일 패턴을 작성하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 간단한 이메일 패턴은 r'[\w\.-]+@[\w\.-]+\.\w+' 형태로 작성할 수 있습니다.
#
# </details>

# %%
import re

text = '문의는 test@example.com 또는 admin@sample.co.kr 로 보내주세요.'

# 이메일 패턴을 작성하세요.
pattern = 

# 이메일을 추출하세요.
emails = 

# 결과를 출력하세요.
emails

# %% [markdown]
# ### 문제 33. XML 문자열 파싱하기 ⭐⭐⭐
#
# XML 문자열에서 item 태그의 name과 price 값을 추출하여 DataFrame으로 만드세요.
#
# **요구사항**
# - xml.etree.ElementTree를 사용하세요.
# - findall()을 사용하세요.
# - DataFrame을 생성하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - ET.fromstring()으로 XML 문자열을 파싱합니다.
#
# </details>

# %%
import pandas as pd
import xml.etree.ElementTree as ET

xml_text = '''
<items>
    <item>
        <name>A상품</name>
        <price>1000</price>
    </item>
    <item>
        <name>B상품</name>
        <price>2000</price>
    </item>
</items>
'''

# XML 문자열을 파싱하세요.
root = 

# item 태그를 모두 찾으세요.
items = 

# 상품 정보를 담을 리스트를 만드세요.
rows = []

# 반복문으로 name과 price를 추출하세요.
for item in items:
    name = 
    price = 
    rows.append({'name': name, 'price': price})

# DataFrame을 생성하세요.
df = 

# 결과를 출력하세요.
df

# %% [markdown]
# ### 문제 34. 크롤링 윤리 체크리스트 작성하기 ⭐⭐
#
# 크롤링을 수행하기 전 확인해야 할 윤리 체크리스트를 리스트로 작성하세요.
#
# **요구사항**
# - checklist 리스트를 만드세요.
# - robots.txt 확인, 요청 간격, 개인정보, 저작권 항목을 포함하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 코드 문제이지만, 실제 현장에서 꼭 필요한 절차를 리스트로 정리하는 문제입니다.
#
# </details>

# %%
# 크롤링 전 확인해야 할 윤리 체크리스트를 작성하세요.
checklist = [
    
]

# 결과를 출력하세요.
checklist
