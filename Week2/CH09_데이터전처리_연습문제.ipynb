# %% [markdown]
# # CH02-04 데이터전처리 연습문제 - 학생용
#
# ## 안내
# - 각 문제를 읽고 코드셀에 직접 코드를 작성하세요.
# - 힌트는 접혀 있습니다. 필요할 때만 펼쳐서 확인하세요.
# - 문제는 기본 → 응용 → 심화 순서로 구성되어 있습니다.

# %% [markdown]
# ## 결측치 처리

# %% [markdown]
# ### 문제 1. 결측치 개수 확인하기 ⭐
#
# 다음 DataFrame에서 컬럼별 결측치 개수를 확인하세요.
#
# **요구사항**
# - isna()를 사용하세요.
# - sum()을 함께 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df.isna().sum() 형태로 작성합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', None],
    'age': [25, np.nan, 30, 28],
    'score': [80, 90, np.nan, 70]
})

# 여기에 코드를 작성하세요
print(df.isna().sum())
# Out:
# name     1
# age      1
# score    1
# dtype: int64

# %% [markdown]
# ### 문제 2. 결측치가 있는 행 제거하기 ⭐
#
# 결측치가 하나라도 포함된 행을 제거하세요.
#
# **요구사항**
# - dropna()를 사용하세요.
# - 결과를 df_clean 변수에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df.dropna()는 결측치가 포함된 행을 제거합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'age': [25, np.nan, 30, 28],
    'score': [80, 90, np.nan, 70]
})

# 여기에 코드를 작성하세요
df_clean = df.dropna()
print(df_clean)
# Out:
#    name   age  score
# 0   Kim  25.0   80.0
# 3  Choi  28.0   70.0

# %% [markdown]
# ### 문제 3. 특정 컬럼 기준으로 결측치 제거하기 ⭐⭐
#
# score 컬럼에 결측치가 있는 행만 제거하세요.
#
# **요구사항**
# - dropna()의 subset 옵션을 사용하세요.
# - 결과를 df_clean 변수에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - subset=['score']를 사용합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'age': [25, np.nan, 30, 28],
    'score': [80, 90, np.nan, 70]
})

# 여기에 코드를 작성하세요
df_clean = df.dropna(subset = ['score'])
print(df_clean)
# Out:
#    name   age  score
# 0   Kim  25.0   80.0
# 1   Lee   NaN   90.0
# 3  Choi  28.0   70.0

# %% [markdown]
# ### 문제 4. 평균값으로 결측치 채우기 ⭐
#
# age 컬럼의 결측치를 age 평균값으로 채우세요.
#
# **요구사항**
# - mean()을 사용하세요.
# - fillna()를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df['age'].mean()으로 평균을 구한 뒤 fillna()에 넣습니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'age': [25, np.nan, 30, 28]
})

# 여기에 코드를 작성하세요
df['age'] = df['age'].fillna(df['age'].mean())
print(df)
# Out:
#    name        age
# 0   Kim  25.000000
# 1   Lee  27.666667
# 2  Park  30.000000
# 3  Choi  28.000000

# %% [markdown]
# ### 문제 5. 최빈값으로 결측치 채우기 ⭐⭐
#
# city 컬럼의 결측치를 최빈값으로 채우세요.
#
# **요구사항**
# - mode()를 사용하세요.
# - fillna()를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - mode() 결과는 Series이므로 첫 번째 값은 mode()[0]으로 가져옵니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi', 'Jung'],
    'city': ['Seoul', 'Busan', 'Seoul', np.nan, 'Seoul']
})

# 여기에 코드를 작성하세요
df['city'] = df['city'].fillna(df['city'].mode()[0])
print(df)
# Out:
#    name   city
# 0   Kim  Seoul
# 1   Lee  Busan
# 2  Park  Seoul
# 3  Choi  Seoul
# 4  Jung  Seoul

# %% [markdown]
# ### 문제 6. 앞의 값으로 결측치 채우기 ⭐⭐
#
# 결측치를 바로 앞 행의 값으로 채우세요.
#
# **요구사항**
# - ffill()을 사용하세요.
# - 결과를 df_filled 변수에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - ffill은 forward fill의 의미입니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'date': ['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04'],
    'price': [1000, np.nan, np.nan, 1200]
})

# 여기에 코드를 작성하세요
df_filled = df['price'].ffill()
print(df_filled)
# Out:
# 0    1000.0
# 1    1000.0
# 2    1000.0
# 3    1200.0
# Name: price, dtype: float64

# %% [markdown]
# ## 이상치 처리

# %% [markdown]
# ### 문제 7. describe로 이상치 후보 확인하기 ⭐
#
# score 컬럼의 기초통계량을 확인하고 이상치 후보가 있는지 살펴보세요.
#
# **요구사항**
# - describe()를 사용하세요.
# - score 컬럼만 선택하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df['score'].describe()를 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'score': [70, 75, 80, 85, 90, 300]
})

# 여기에 코드를 작성하세요
df['score'].describe()
# Out:
# count      6.000000
# mean     116.666667
# std       90.092545
# min       70.000000
# 25%       76.250000
# 50%       82.500000
# 75%       88.750000
# max      300.000000
# Name: score, dtype: float64

# %% [markdown]
# ### 문제 8. 조건 검색으로 이상치 찾기 ⭐
#
# score가 100보다 큰 행을 추출하세요.
#
# **요구사항**
# - 조건 검색을 사용하세요.
# - 결과를 outliers 변수에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df[df['score'] > 100] 형태로 작성합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'score': [80, 90, 120, 70]
})

# 여기에 코드를 작성하세요
outliers = df[df['score'] > 100]
print(outliers)
# Out:
#   name  score
# 2    C    120

# %% [markdown]
# ### 문제 9. 이상치를 특정 값으로 대체하기 ⭐⭐
#
# score가 100보다 큰 값을 100으로 대체하세요.
#
# **요구사항**
# - loc를 사용하세요.
# - score 컬럼의 값만 수정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df.loc[조건, 'score'] = 100 형태로 작성합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['A', 'B', 'C', 'D'],
    'score': [80, 90, 120, 70]
})

# 여기에 코드를 작성하세요
df.loc[df['score'] > 100, 'score'] = 100
print(df)
# Out:
#   name  score
# 0    A     80
# 1    B     90
# 2    C    100
# 3    D     70

# %% [markdown]
# ### 문제 10. IQR 방식으로 이상치 기준 계산하기 ⭐⭐⭐
#
# score 컬럼에 대해 IQR 방식의 하한선과 상한선을 계산하세요.
#
# **요구사항**
# - quantile()을 사용하세요.
# - Q1, Q3, IQR을 계산하세요.
# - lower, upper 변수를 만드세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - IQR = Q3 - Q1, lower = Q1 - 1.5 * IQR, upper = Q3 + 1.5 * IQR입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'score': [60, 65, 70, 75, 80, 85, 90, 200]
})

# 여기에 코드를 작성하세요
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
print("하한선 : ", lower, "상한선 : ", upper)
# Out:
# 하한선 :  score    42.5
# dtype: float64 상한선 :  score    112.5
# dtype: float64

# %% [markdown]
# ### 문제 11. IQR 기준으로 이상치 제거하기 ⭐⭐⭐
#
# IQR 기준을 사용하여 이상치가 아닌 데이터만 남기세요.
#
# **요구사항**
# - lower 이상, upper 이하인 행만 선택하세요.
# - 결과를 df_clean 변수에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 두 조건은 & 연산자로 연결합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'score': [60, 65, 70, 75, 80, 85, 90, 200]
})

# 여기에 코드를 작성하세요
Q1 = df['score'].quantile(0.25)
Q3 = df['score'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
df_clean = df[(df['score'] >= lower) & (df['score'] <= upper)]
print(df_clean)
# Out:
#    score
# 0     60
# 1     65
# 2     70
# 3     75
# 4     80
# 5     85
# 6     90

# %% [markdown]
# ## 자료형 변환

# %% [markdown]
# ### 문제 12. 문자열 숫자를 정수형으로 변환하기 ⭐
#
# age 컬럼이 문자열로 저장되어 있습니다. 정수형으로 변환하세요.
#
# **요구사항**
# - astype(int)를 사용하세요.
# - 변환 후 dtypes를 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df['age'] = df['age'].astype(int) 형태로 작성합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park'],
    'age': ['25', '30', '28']
})

# 여기에 코드를 작성하세요
print(df['age'].astype(int))
print(df['age'].astype(int).dtypes)
# Out:
# 0    25
# 1    30
# 2    28
# Name: age, dtype: int64
# int64

# %% [markdown]
# ### 문제 13. 날짜 문자열을 datetime으로 변환하기 ⭐⭐
#
# date 컬럼을 datetime 자료형으로 변환하세요.
#
# **요구사항**
# - pd.to_datetime()을 사용하세요.
# - 변환 후 dtypes를 확인하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - pd.to_datetime(df['date'])를 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'date': ['2026-01-01', '2026-01-02', '2026-01-03'],
    'sales': [100, 120, 130]
})

# 여기에 코드를 작성하세요
print(pd.to_datetime(df['date']))
print(pd.to_datetime(df['date']).dtypes)
# Out:
# 0   2026-01-01
# 1   2026-01-02
# 2   2026-01-03
# Name: date, dtype: datetime64[ns]
# datetime64[ns]

# %% [markdown]
# ### 문제 14. replace로 값 바꾸기 ⭐
#
# gender 컬럼의 'M'은 'Male', 'F'는 'Female'로 변경하세요.
#
# **요구사항**
# - replace()를 사용하세요.
# - 변환 결과를 기존 gender 컬럼에 저장하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 딕셔너리를 사용하여 여러 값을 한 번에 바꿀 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park'],
    'gender': ['M', 'F', 'M']
})

# 여기에 코드를 작성하세요
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1858/3039180946.py in <cell line: 0>()
#       7
#       8 # 여기에 코드를 작성하세요
# ----> 9 df['gender'] = df['gender'].str.replace({
#      10     'M' : "Male", 'F' : "Female"
#      11 })
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     135                 )
#     136                 raise TypeError(msg)
# --> 137             return func(self, *args, **kwargs)
#     138
#     139         wrapper.__name__ = func_name
#
# TypeError: StringMethods.replace() missing 1 required positional argument: 'repl'

# %% [markdown]
# ### 문제 15. map으로 등급 점수화하기 ⭐⭐
#
# grade 컬럼의 A, B, C를 각각 3, 2, 1로 변환한 grade_score 컬럼을 만드세요.
#
# **요구사항**
# - map()을 사용하세요.
# - 새 컬럼 grade_score를 생성하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df['grade'].map({'A': 3, 'B': 2, 'C': 1}) 형태로 작성합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'grade': ['A', 'B', 'C', 'A']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 16. 문자열 금액에서 쉼표 제거 후 숫자로 변환하기 ⭐⭐
#
# price 컬럼의 쉼표를 제거하고 정수형으로 변환하세요.
#
# **요구사항**
# - str.replace()를 사용하세요.
# - astype(int)를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 문자열 메서드는 df['price'].str.replace(',', '') 형태로 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'product': ['A', 'B', 'C'],
    'price': ['1,000', '2,500', '3,200']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 데이터 병합

# %% [markdown]
# ### 문제 17. merge로 두 DataFrame 병합하기 ⭐⭐
#
# 학생 정보 df_students와 점수 정보 df_scores를 student_id 기준으로 병합하세요.
#
# **요구사항**
# - pd.merge()를 사용하세요.
# - on='student_id'를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 공통 컬럼을 기준으로 병합할 때 on 옵션을 사용합니다.
#
# </details>

# %%
import pandas as pd

df_students = pd.DataFrame({
    'student_id': [1, 2, 3],
    'name': ['Kim', 'Lee', 'Park']
})

df_scores = pd.DataFrame({
    'student_id': [1, 2, 3],
    'score': [80, 90, 85]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 18. left join 사용하기 ⭐⭐
#
# 학생 정보를 기준으로 점수 정보를 left join 하세요.
#
# **요구사항**
# - pd.merge()를 사용하세요.
# - how='left'를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 왼쪽 DataFrame의 모든 행을 유지하려면 how='left'를 사용합니다.
#
# </details>

# %%
import pandas as pd

df_students = pd.DataFrame({
    'student_id': [1, 2, 3, 4],
    'name': ['Kim', 'Lee', 'Park', 'Choi']
})

df_scores = pd.DataFrame({
    'student_id': [1, 2, 3],
    'score': [80, 90, 85]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 19. concat으로 행 방향 결합하기 ⭐
#
# 두 개의 DataFrame을 행 방향으로 이어 붙이세요.
#
# **요구사항**
# - pd.concat()을 사용하세요.
# - ignore_index=True를 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 행 방향 결합은 기본 axis=0입니다.
#
# </details>

# %%
import pandas as pd

df1 = pd.DataFrame({
    'name': ['Kim', 'Lee'],
    'score': [80, 90]
})

df2 = pd.DataFrame({
    'name': ['Park', 'Choi'],
    'score': [85, 88]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 20. concat으로 열 방향 결합하기 ⭐⭐
#
# 학생 이름 DataFrame과 점수 DataFrame을 열 방향으로 결합하세요.
#
# **요구사항**
# - pd.concat()을 사용하세요.
# - axis=1을 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 열 방향 결합은 axis=1입니다.
#
# </details>

# %%
import pandas as pd

df_names = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park']
})

df_scores = pd.DataFrame({
    'score': [80, 90, 85]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## apply 활용

# %% [markdown]
# ### 문제 21. apply로 점수 등급 만들기 ⭐⭐
#
# score가 90 이상이면 A, 80 이상이면 B, 그 외는 C를 반환하는 grade 컬럼을 만드세요.
#
# **요구사항**
# - 함수를 정의하세요.
# - apply()를 사용하세요.
# - 새 컬럼 grade를 생성하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - def get_grade(score): 형태로 함수를 만든 뒤 apply에 전달합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'score': [95, 85, 72, 90]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 22. lambda와 apply 함께 사용하기 ⭐⭐
#
# price 컬럼에 10% 할인된 가격을 계산하여 discount_price 컬럼을 만드세요.
#
# **요구사항**
# - lambda 함수를 사용하세요.
# - apply()를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - x * 0.9를 반환하면 10% 할인 가격입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'product': ['A', 'B', 'C'],
    'price': [10000, 20000, 15000]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 23. 행 단위 apply 사용하기 ⭐⭐⭐
#
# math와 english 평균을 계산하여 avg 컬럼을 만드세요.
#
# **요구사항**
# - apply()를 사용하세요.
# - axis=1을 설정하세요.
# - 새 컬럼 avg를 생성하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 행 단위 적용은 axis=1입니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park'],
    'math': [80, 90, 70],
    'english': [85, 88, 75]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 24. 복합 조건으로 합격 여부 만들기 ⭐⭐⭐
#
# math와 english가 모두 70 이상이면 Pass, 아니면 Fail을 반환하는 result 컬럼을 만드세요.
#
# **요구사항**
# - 함수를 정의하세요.
# - axis=1 apply를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - row['math']와 row['english']를 함께 사용합니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'math': [80, 65, 90, 72],
    'english': [75, 80, 60, 78]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 종합문제

# %% [markdown]
# ### 문제 25. 결측치 처리와 자료형 변환 종합 ⭐⭐⭐
#
# 주어진 고객 데이터에서 age 결측치는 평균으로 채우고, income의 쉼표를 제거한 뒤 정수형으로 변환하세요.
#
# **요구사항**
# - age 결측치를 평균으로 채우세요.
# - income 컬럼의 쉼표를 제거하세요.
# - income을 int로 변환하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - fillna, str.replace, astype을 순서대로 활용합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'age': [25, np.nan, 30, 28],
    'income': ['3,000', '4,500', '5,200', '3,800']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 26. 병합 후 파생변수 만들기 ⭐⭐⭐
#
# 고객 정보와 구매 정보를 병합한 뒤, 구매금액이 100000 이상이면 VIP, 아니면 Normal인 customer_type 컬럼을 만드세요.
#
# **요구사항**
# - customer_id 기준으로 merge하세요.
# - apply 또는 lambda를 사용하세요.
# - customer_type 컬럼을 생성하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 먼저 pd.merge()를 수행한 뒤 amount 컬럼에 apply를 적용합니다.
#
# </details>

# %%
import pandas as pd

customers = pd.DataFrame({
    'customer_id': [1, 2, 3],
    'name': ['Kim', 'Lee', 'Park']
})

orders = pd.DataFrame({
    'customer_id': [1, 2, 3],
    'amount': [120000, 80000, 150000]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 심화: applymap / pipe

# %% [markdown]
# ### 문제 27. applymap으로 전체 문자열 정리하기 ⭐⭐⭐
#
# DataFrame의 모든 문자열 값에서 앞뒤 공백을 제거하세요.
#
# **요구사항**
# - applymap()을 사용하세요.
# - 문자열인 경우에만 strip()을 적용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - isinstance(x, str)을 사용하여 문자열 여부를 확인할 수 있습니다.
#
# </details>

# %%
import pandas as pd

df = pd.DataFrame({
    'name': [' Kim ', ' Lee ', ' Park '],
    'city': [' Seoul ', ' Busan ', ' Jeju ']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 28. pipe로 전처리 함수 연결하기 ⭐⭐⭐
#
# 결측치를 제거하는 함수와 인덱스를 초기화하는 함수를 만든 뒤 pipe로 연결하세요.
#
# **요구사항**
# - drop_missing 함수를 정의하세요.
# - reset_idx 함수를 정의하세요.
# - pipe()를 두 번 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - df.pipe(함수1).pipe(함수2) 형태로 연결합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', None, 'Park'],
    'score': [80, 90, 85, np.nan]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 29. pipe로 여러 전처리 단계 연결하기 ⭐⭐⭐
#
# income 컬럼의 쉼표를 제거하고 정수형으로 변환하는 함수, age 결측치를 평균으로 채우는 함수를 만든 뒤 pipe로 연결하세요.
#
# **요구사항**
# - clean_income 함수를 정의하세요.
# - fill_age 함수를 정의하세요.
# - pipe()로 두 함수를 연결하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 각 함수는 DataFrame을 입력받고 수정된 DataFrame을 반환해야 합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park'],
    'age': [25, np.nan, 30],
    'income': ['3,000', '4,500', '5,200']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 30. apply와 pipe를 함께 활용하기 ⭐⭐⭐
#
# 점수 결측치를 평균으로 채우고, apply를 사용해 grade 컬럼을 만드는 전처리 함수를 작성한 뒤 pipe로 실행하세요.
#
# **요구사항**
# - 전처리 함수 preprocess를 정의하세요.
# - 함수 내부에서 fillna와 apply를 사용하세요.
# - df.pipe(preprocess)를 실행하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - preprocess 함수는 DataFrame을 입력받아 처리된 DataFrame을 반환해야 합니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': ['Kim', 'Lee', 'Park', 'Choi'],
    'score': [95, np.nan, 72, 88]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 31. 전처리 파이프라인 종합문제 ⭐⭐⭐
#
# 고객 데이터에서 문자열 공백 제거, 나이 결측치 처리, 구매금액 숫자 변환, 고객등급 생성을 하나의 파이프라인으로 처리하세요.
#
# **요구사항**
# - 문자열 공백을 제거하세요.
# - age 결측치를 평균으로 채우세요.
# - amount의 쉼표를 제거하고 정수형으로 변환하세요.
# - amount가 100000 이상이면 VIP, 아니면 Normal을 부여하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - clean_text, fill_age, clean_amount, make_grade 함수를 각각 만들고 pipe로 연결할 수 있습니다.
#
# </details>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'name': [' Kim ', ' Lee ', ' Park '],
    'age': [25, np.nan, 32],
    'amount': ['120,000', '80,000', '150,000']
})

# 여기에 코드를 작성하세요
