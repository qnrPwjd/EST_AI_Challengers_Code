# %% [markdown]
# ### ☀️ 참고 ☀️ 한글깨짐 방지
#
# - 아래 코드셀 3개 실행 필수
# - 윈도우, 맥 동일
#
# ❗️주의❗️
# - Step1. 첫째 셀 실행
# - Step2. '런타임 > 세션 다시시작'
# - Step3. 이후 두번째 셀 실행

# %%
# 나눔 폰트 설치
# 해당 셀 실행 후 '런타임 > 세션 다시 시작'

# %%capture

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl


# 나눔고딕 폰트 사용 설정 (폰트 설치 후 실행)
plt.rcParams["font.family"]="NanumGothic"

# 마이너스 깨짐 방지 (일반 하이픈(-)을 사용하게 설정)
mpl.rcParams['axes.unicode_minus'] = False

# %%
# 한글 폰트 테스트 그래프

plt.plot([1, 2, 3], [10, -20, 30])
plt.title('한글 폰트 테스트')
plt.xlabel('x축')
plt.ylabel('y축')
plt.grid(True)
plt.show()

# %% [markdown]
# # AICE Associate 특강 모의고사
#
# ## 스터디카페 이용 데이터 EDA 분석
#
# 스터디카페 이용 데이터를 읽어들여 탐색적 데이터 분석(EDA)과 시각화를 통해 데이터의 특성과 인사이트를 도출하세요.
#
# ---
# reservation_id: 예약 고유번호 <br>
# branch: 지점명 (강남점, 홍대점, 신촌점, 건대점, 잠실점) <br>
# seat_type: 좌석 타입 (오픈석, 개인석, 스터디룸) <br>
# age_group: 연령대 (10대, 20대, 30대, 40대이상) <br>
# day_type: 요일 구분 (평일, 주말) <br>
# usage_minutes: 이용 시간(분) <br>
# rate_per_hour: 시간당 요금(원) <br>
# visit_count: 당월 누적 방문 횟수 <br>
# membership: 멤버십 가입 여부 (Y/N) <br>
# satisfaction: 이용 만족도 (1~5점) <br>
# currency: 결제 통화 <br>
#
# ---

# %% [markdown]
# ### 1. Pandas 라이브러리를 별칭 pd로 임포트하는 코드를 작성하고 실행하세요.
# ---
# - 설치되어 있지 않으면 설치해서 임포트하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.
import pandas as pd

# %% [markdown]
# 다음 문항을 풀기 전에 아래의 코드를 실행하세요.

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %% [markdown]
# ### 2. 모델링을 위해 분석할 데이터 파일을 읽어오려고 합니다.
# ---
# pandas 함수로 데이터 파일을 읽고 데이터프레임 변수명 df에 할당하는 코드를 작성하세요.
# - study_cafe_usage.csv 파일을 읽어 df에 할당하세요.
# - 데이터프레임의 정보와 기초통계량을 확인하는 코드를 작성하세요.
# - 출력된 결과와 일치하지 않는 내용을 아래에서 골라 "답안02" 변수에 저장하세요. (예: 답안02=1)
#     1. 데이터의 총 행(row)의 개수는 1,500개이다.
#     2. 총 11개의 컬럼으로 구성되어 있다.
#     3. usage_minutes(이용시간)의 평균은 약 215분이다.
#     4. 결측치가 존재하는 컬럼이 있다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
df = pd.read_csv('study_cafe_usage.csv')

print(df.info())
print(df.describe())

답안02 = 4
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reservation_id  1500 non-null   object
#  1   branch          1500 non-null   object
#  2   seat_type       1500 non-null   object
#  3   age_group       1500 non-null   object
#  4   day_type        1500 non-null   object
#  5   usage_minutes   1500 non-null   int64
#  6   rate_per_hour   1500 non-null   int64
#  7   visit_count     1500 non-null   int64
#  8   membership      1500 non-null   object
#  9   satisfaction    1500 non-null   int64
#  10  currency        1500 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 129.0+ KB
# None
#        usage_minutes  rate_per_hour  visit_count  satisfaction
# count    1500.000000    1500.000000  1500.000000    1500.00000
# mean      215.365333    2889.533333     4.998667       3.49400
# ...

# %% [markdown]
# ### 3. 좌석 타입(seat_type)에 따른 평균 이용 시간(usage_minutes)을 비교해 보려고 합니다.
# ---
# 아래 가이드를 따라 barplot을 시각화하세요.
# - 대상 데이터프레임: df
# - Seaborn의 barplot을 활용하세요.
#     - x: seat_type, y: usage_minutes
# - 그래프를 보고 해석한 것으로 옳은 선택지를 아래에서 골라 "답안03" 변수에 저장하세요. (예: 답안03=1)
#     1. 스터디룸을 이용하는 고객의 평균 이용 시간이 가장 길다.
#     2. 오픈석의 평균 이용 시간은 250분을 넘는다.
#     3. 개인석의 평균 이용 시간이 오픈석보다 짧다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
import seaborn as sns

sns.barplot(data = df, x = 'seat_type', y = 'usage_minutes')
plt.show()

답안03 = 1

# %% [markdown]
# ### 4. 좌석 타입(seat_type)별로 이용 만족도(satisfaction)의 평균을 구하세요.
# ---
# - 대상 데이터프레임: df
# - groupby를 사용하여 제시한 조건에 대한 통계를 구하세요.
# - 출력된 결과를 보고 해석한 것으로 옳지 않은 선택지를 아래에서 골라 "답안04" 변수에 저장하세요. (예: 답안04=1)
#     1. 스터디룸의 평균 만족도가 가장 높다.
#     2. 오픈석의 평균 만족도는 3.5를 넘는다.
#     3. 개인석의 평균 만족도는 3.5 이상이다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
group = df.groupby('seat_type')['satisfaction'].mean()
display(group)

답안04 = 2
# Out:
# seat_type
# 개인석     3.583019
# 스터디룸    3.933718
# 오픈석     3.173355
# Name: satisfaction, dtype: float64

# %% [markdown]
# ### 5. 전체 이용 시간(usage_minutes)의 분포를 확인하려고 합니다.
# ---
# - 대상 데이터프레임: df
# - Seaborn의 histplot을 활용하여 시각화하세요.
#     - 막대의 수(bins)는 30으로 설정하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.
sns.histplot(data = df, x = 'usage_minutes', bins = 30)
plt.show()

# %% [markdown]
# ### 6. usage_minutes와 rate_per_hour 컬럼을 활용하여 파생변수를 생성하세요.
# ---
# 다음 가이드를 따라 코드를 작성하세요.
# - 대상 데이터프레임: df
# - 이용 시간(usage_minutes, 분)을 시간 단위로 환산한 뒤 시간당 요금(rate_per_hour)을 곱하여 총 결제금액 파생변수(total_payment)를 생성하세요.
# - 파생변수가 추가된 결과를 새로운 데이터프레임 변수명 df_add에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.
df_add = df.copy()
df_add['total_payment'] = df_add['usage_minutes'] / 60 * df_add['rate_per_hour']

df_add.head()
# Out:
#   reservation_id branch seat_type age_group day_type  usage_minutes  \
# 0       RSV00001    홍대점       개인석       30대       평일            176
# 1       RSV00002    잠실점       개인석       30대       평일             62
# 2       RSV00003    건대점       오픈석       20대       평일            127
# 3       RSV00004    신촌점       오픈석       30대       평일            181
# 4       RSV00005    강남점       오픈석       20대       평일            119
#
#    rate_per_hour  visit_count membership  satisfaction currency  total_payment
# 0           2300            2          N             3      KRW    6746.666667
# 1           2600            8          Y             3      KRW    2686.666667
# 2           1500            8          N             3      KRW    3175.000000
# 3           1600            6          Y             3      KRW    4826.666667
# 4           1400            6          N             3      KRW    2776.666667

# %% [markdown]
# ### 7. 연령대(age_group)에 따른 평균 총 결제금액(total_payment)을 비교해 보려고 합니다.
# ---
# 아래 가이드를 따라 barplot을 시각화하세요.
# - 대상 데이터프레임: df_add
# - Seaborn의 barplot을 활용하세요.
#     - x: age_group, y: total_payment
# - 그래프를 보고 해석한 것으로 옳은 선택지를 아래에서 골라 "답안07" 변수에 저장하세요. (예: 답안07=1)
#     1. 20대의 평균 결제금액이 가장 높다.
#     2. 40대이상의 평균 결제금액이 10대보다 높다.
#     3. 30대의 평균 결제금액은 11,000원을 넘는다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
sns.barplot(data = df_add, x = 'age_group', y = 'total_payment')
plt.show()

답안07 = 1

# %% [markdown]
# ### 8. 분석에 불필요한 컬럼을 삭제하세요.
# ---
# 다음 가이드를 따라 코드를 작성하세요.
# - 대상 데이터프레임: df_add
# - 제거할 컬럼: reservation_id, currency
#     - reservation_id는 예약 건마다 고유한 값으로 분석에 의미가 없습니다.
#     - currency는 모든 행의 값이 "KRW"로 동일하여 분석에 의미가 없습니다.
# - 전처리 반영된 결과를 새로운 데이터프레임 변수명 df_del에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요.
df_del = df_add.drop(['reservation_id', 'currency'], axis = 1)

df_del.head()
# Out:
#   branch seat_type age_group day_type  usage_minutes  rate_per_hour  \
# 0    홍대점       개인석       30대       평일            176           2300
# 1    잠실점       개인석       30대       평일             62           2600
# 2    건대점       오픈석       20대       평일            127           1500
# 3    신촌점       오픈석       30대       평일            181           1600
# 4    강남점       오픈석       20대       평일            119           1400
#
#    visit_count membership  satisfaction  total_payment
# 0            2          N             3    6746.666667
# 1            8          Y             3    2686.666667
# 2            8          N             3    3175.000000
# 3            6          Y             3    4826.666667
# 4            6          N             3    2776.666667

# %% [markdown]
# ### 9. 수치형 변수들의 상관관계를 확인하세요.
# ---
# 다음 가이드를 따라 그래프를 시각화하세요.
# - 대상 데이터프레임: df_del
# - seaborn을 사용하세요.
#     - 그래프 안에 상관계수 수치를 표시하세요.
# - 출력된 결과를 보고 해석한 것으로 옳지 않은 선택지를 아래에서 골라 "답안09" 변수에 저장하세요. (예: 답안09=1)
#     1. total_payment와 가장 상관관계가 높은 변수는 rate_per_hour이다.
#     2. visit_count와 satisfaction은 강한 양의 상관관계를 가진다.
#     3. usage_minutes와 total_payment는 양의 상관관계를 가진다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
corr = df_del.corr(numeric_only = True)

sns.heatmap(corr, annot = True)
plt.show()

답안09 = 2

# %% [markdown]
# ### 10. 좌석 타입(seat_type)별 총 결제금액(total_payment)의 분포를 확인해 보려고 합니다.
# ---
# 다음 가이드를 따라 그래프를 시각화하세요.
# - 대상 데이터프레임: df_del
# - Seaborn의 boxplot을 활용하세요.
#     - x: seat_type, y: total_payment
# - 출력된 그래프를 보고 해석한 것으로 옳은 선택지를 아래에서 골라 "답안10" 변수에 저장하세요. (예: 답안10=1)
#     1. 스터디룸의 결제금액 중앙값이 가장 높다.
#     2. 오픈석과 개인석의 결제금액 분포는 차이가 거의 없다.
#     3. 좌석 타입에 관계없이 결제금액의 분포는 비슷하다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
sns.boxplot(df_del, x = 'seat_type', y = 'total_payment')
plt.show()

답안10 = 1

# %% [markdown]
# ### 11. 이용 시간(usage_minutes)과 만족도(satisfaction)의 관계를 확인해 보려고 합니다.
# ---
# 다음 가이드를 따라 그래프를 시각화하세요.
# - 대상 데이터프레임: df_del
# - Seaborn의 scatterplot을 활용하세요.
#     - x: usage_minutes, y: satisfaction
# - 출력된 그래프를 보고 해석한 것으로 옳은 선택지를 아래에서 골라 "답안11" 변수에 저장하세요. (예: 답안11=1)
#     1. 이용 시간이 길수록 만족도가 대체로 높아지는 경향을 보인다.
#     2. 이용 시간과 만족도는 뚜렷한 음의 관계를 보인다.
#     3. 이용 시간에 관계없이 만족도는 항상 일정하다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
sns.scatterplot(df_del, x = 'usage_minutes', y = 'satisfaction')
plt.show()

답안11 = 1

# %% [markdown]
# ### 12. 요일 구분(day_type)에 따른 좌석 타입(seat_type) 이용 현황을 교차표로 확인해 보려고 합니다.
# ---
# 다음 가이드를 따라 코드를 작성하세요.
# - 대상 데이터프레임: df_del
# - pandas의 crosstab 함수를 활용하여 day_type과 seat_type의 교차표를 구하세요.
# - 출력된 결과를 보고 해석한 것으로 옳지 않은 선택지를 아래에서 골라 "답안12" 변수에 저장하세요. (예: 답안12=1)
#     1. 평일과 주말 모두 오픈석 이용 비율이 가장 높다.
#     2. 주말의 개인석 이용 건수는 200건이 넘는다.
#     3. 평일의 스터디룸 이용 건수는 200건이 넘는다.
# ---

# %%
# 여기에 답안코드를 작성하세요.
cross = pd.crosstab(df_del['day_type'], df['seat_type'])
cross

답안12 = 2
# Out:
# seat_type  개인석  스터디룸  오픈석
# day_type
# 주말         176   124  217
# 평일         354   223  406

# %% [markdown]
# ### 13. 지점(branch)과 좌석 타입(seat_type)에 따른 평균 결제금액(total_payment)을 종합적으로 확인해 보려고 합니다.
# ---
# 다음 가이드를 따라 코드를 작성하세요.
# - 대상 데이터프레임: df_del
# - pandas의 pivot_table 함수를 활용하여 branch를 행(index), seat_type을 열(columns), total_payment의 평균을 값(values)으로 하는 피벗 테이블을 만드세요.
# - 위에서 만든 피벗 테이블을 Seaborn의 heatmap으로 시각화하세요.
#     - 그래프 안에 수치를 표시하세요.
# - 평균 결제금액이 가장 높은 지점-좌석타입 조합을 "답안13" 변수에 저장하세요. (예: 답안13="강남점-오픈석")
# ---

# %%
# 여기에 답안코드를 작성하세요.
pivot = df_del.pivot_table(index = 'branch', columns = 'seat_type',
                           values = 'total_payment', aggfunc = 'mean')
display(pivot)

sns.heatmap(pivot, annot = True, fmt = '.0f')
plt.show()

답안13 = "건대점-스터디룸"
# Out:
# seat_type          개인석          스터디룸          오픈석
# branch
# 강남점        9110.735931  23938.055556  4760.320911
# 건대점        9649.098039  24309.627193  5196.586667
# 신촌점        8896.383648  22525.497076  4957.424242
# 잠실점        9006.522634  24448.025641  4992.542955
# 홍대점        9297.532051  23887.512821  4861.820513

# %% [markdown]
# ---
# 이상으로 EDA 실전 모의고사를 마칩니다. 수고하셨습니다!
