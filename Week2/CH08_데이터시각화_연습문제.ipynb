# %% [markdown]
# # CH08 시각화 연습문제 - 학생용
#
# ## 안내
# - 각 문제를 읽고 코드셀에 직접 코드를 작성하세요.
# - 힌트는 접혀 있습니다. 필요할 때만 펼쳐서 확인하세요.
# - 문제는 기본 → 응용 → 심화 순서로 구성되어 있습니다.

# %% [markdown]
# ## Matplotlib 기초

# %% [markdown]
# ### 문제 1. Matplotlib 기본 선 그래프 그리기 ⭐
#
# x = [1, 2, 3, 4, 5], y = [10, 20, 15, 25, 30] 데이터를 사용하여 기본 선 그래프를 그리세요.
#
# **요구사항**
# - matplotlib.pyplot을 plt로 불러오세요.
# - plt.plot()을 사용하세요.
# - 그래프를 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - plt.plot(x, y)를 사용합니다.
# - 마지막에 plt.show()를 작성하면 그래프가 출력됩니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 그래프 제목과 축 이름 추가하기 ⭐
#
# 매출 데이터를 선 그래프로 그리고 제목, x축 이름, y축 이름을 추가하세요.
#
# **요구사항**
# - title은 'Monthly Sales'로 설정하세요.
# - x축 이름은 'Month'로 설정하세요.
# - y축 이름은 'Sales'로 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - plt.title()
# - plt.xlabel()
# - plt.ylabel()을 사용합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr']
sales = [120, 150, 130, 180]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 마커와 선 스타일 지정하기 ⭐
#
# 선 그래프에 원형 마커와 점선 스타일을 적용하세요.
#
# **요구사항**
# - marker='o'를 사용하세요.
# - linestyle='--'를 사용하세요.
# - 그래프 제목을 추가하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - plt.plot() 안에 marker와 linestyle 옵션을 넣습니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [3, 6, 5, 8, 7]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 막대 그래프 그리기 ⭐
#
# 카테고리별 판매량 데이터를 막대 그래프로 시각화하세요.
#
# **요구사항**
# - plt.bar()를 사용하세요.
# - 제목과 축 이름을 추가하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 범주형 데이터 비교에는 bar plot이 적합합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

products = ['A', 'B', 'C', 'D']
sales = [35, 52, 28, 44]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 5. 수평 막대 그래프 그리기 ⭐
#
# 지역별 매출 데이터를 수평 막대 그래프로 표현하세요.
#
# **요구사항**
# - plt.barh()를 사용하세요.
# - 제목을 추가하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 수평 막대 그래프는 plt.barh()를 사용합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

regions = ['Seoul', 'Busan', 'Jeju', 'Daegu']
sales = [120, 90, 70, 85]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 6. 산점도 그리기 ⭐
#
# 공부시간과 시험점수의 관계를 산점도로 표현하세요.
#
# **요구사항**
# - plt.scatter()를 사용하세요.
# - x축은 study_hours, y축은 scores로 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 두 수치형 변수의 관계는 scatter plot으로 확인합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5, 6]
scores = [50, 55, 65, 70, 75, 85]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 7. 히스토그램 그리기 ⭐
#
# 학생 점수 데이터의 분포를 히스토그램으로 표현하세요.
#
# **요구사항**
# - plt.hist()를 사용하세요.
# - bins=5로 설정하세요.
# - 제목을 추가하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 분포를 볼 때는 histogram을 사용합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

scores = [55, 60, 62, 70, 72, 75, 80, 85, 88, 90, 95]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 8. 여러 선 그래프와 범례 추가하기 ⭐⭐
#
# 두 지점의 월별 매출을 하나의 그래프에 그리고 범례를 추가하세요.
#
# **요구사항**
# - Seoul과 Busan 데이터를 각각 선 그래프로 그리세요.
# - label을 지정하세요.
# - plt.legend()를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - plt.plot()을 두 번 사용하고, 각각 label을 지정합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr']
seoul = [120, 150, 130, 180]
busan = [100, 130, 125, 160]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 9. figure 크기 조정하기 ⭐
#
# 그래프의 크기를 가로 8, 세로 4로 설정하여 선 그래프를 그리세요.
#
# **요구사항**
# - plt.figure(figsize=(8, 4))를 사용하세요.
# - 선 그래프를 그리세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 그래프 크기는 plt.figure()에서 figsize로 설정합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 15, 13, 20]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 10. 그리드 추가하기 ⭐
#
# 선 그래프에 그리드를 추가하세요.
#
# **요구사항**
# - plt.grid(True)를 사용하세요.
# - 제목을 추가하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 격자선은 grid() 함수로 설정합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# 여기에 코드를 작성하세요

# %% [markdown]
# ## Seaborn 기초

# %% [markdown]
# ### 문제 11. Seaborn으로 막대 그래프 그리기 ⭐
#
# Seaborn을 사용하여 카테고리별 평균 점수를 막대 그래프로 표현하세요.
#
# **요구사항**
# - seaborn을 sns로 불러오세요.
# - sns.barplot()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - Seaborn은 DataFrame 기반 시각화에 자주 사용됩니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'class': ['A', 'B', 'C', 'D'],
    'score': [85, 78, 92, 88]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 12. Seaborn countplot 사용하기 ⭐
#
# 성별 데이터의 개수를 countplot으로 시각화하세요.
#
# **요구사항**
# - sns.countplot()을 사용하세요.
# - x축에는 gender 컬럼을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - countplot은 범주별 빈도수를 자동으로 계산합니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'gender': ['M', 'F', 'F', 'M', 'F', 'M', 'F']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 13. Seaborn scatterplot 사용하기 ⭐
#
# 키와 몸무게의 관계를 Seaborn 산점도로 표현하세요.
#
# **요구사항**
# - sns.scatterplot()을 사용하세요.
# - x는 height, y는 weight로 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - Seaborn은 data=df, x='컬럼명', y='컬럼명' 형식으로 자주 씁니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'height': [160, 165, 170, 175, 180],
    'weight': [55, 60, 68, 72, 80]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 14. hue 옵션으로 그룹 구분하기 ⭐⭐
#
# 공부시간과 점수의 관계를 산점도로 그리고, 성별에 따라 색상을 다르게 표현하세요.
#
# **요구사항**
# - sns.scatterplot()을 사용하세요.
# - hue='gender'를 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - hue는 색상으로 그룹을 구분할 때 사용합니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'study_hours': [1, 2, 3, 4, 5, 6],
    'score': [50, 60, 65, 70, 80, 85],
    'gender': ['M', 'F', 'M', 'F', 'M', 'F']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 15. boxplot으로 이상치 확인하기 ⭐⭐
#
# 반별 점수 분포를 boxplot으로 시각화하세요.
#
# **요구사항**
# - sns.boxplot()을 사용하세요.
# - x축은 class, y축은 score로 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - boxplot은 중앙값, 사분위수, 이상치를 함께 보여줍니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'class': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'score': [70, 75, 100, 60, 65, 90, 80, 85, 88]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 16. heatmap으로 상관관계 시각화하기 ⭐⭐
#
# 수치형 변수들의 상관계수를 구하고 heatmap으로 시각화하세요.
#
# **요구사항**
# - df.corr()를 사용하세요.
# - sns.heatmap()을 사용하세요.
# - annot=True를 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 상관관계는 corr(), 시각화는 heatmap()을 사용합니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'math': [80, 90, 70, 60, 85],
    'english': [75, 88, 72, 65, 80],
    'science': [90, 92, 68, 70, 88]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## subplot

# %% [markdown]
# ### 문제 17. subplot으로 그래프 2개 그리기 ⭐⭐
#
# 하나의 화면에 선 그래프와 막대 그래프를 나란히 배치하세요.
#
# **요구사항**
# - plt.subplot(1, 2, 1)을 사용하세요.
# - plt.subplot(1, 2, 2)을 사용하세요.
# - plt.tight_layout()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - subplot(행, 열, 위치) 형식입니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]
products = ['A', 'B', 'C']
sales = [30, 50, 40]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 18. 2행 2열 subplot 만들기 ⭐⭐
#
# 2행 2열 구조로 선 그래프, 막대 그래프, 산점도, 히스토그램을 각각 그리세요.
#
# **요구사항**
# - plt.subplot(2, 2, n)을 사용하세요.
# - 총 4개의 그래프를 배치하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 2행 2열은 subplot(2, 2, 1)부터 subplot(2, 2, 4)까지 사용합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
categories = ['A', 'B', 'C']
values = [10, 20, 15]
scores = [60, 65, 70, 75, 80, 85, 90]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 19. subplots 객체 방식 사용하기 ⭐⭐⭐
#
# plt.subplots()를 사용하여 1행 2열 그래프를 작성하세요.
#
# **요구사항**
# - fig, axes = plt.subplots(1, 2)를 사용하세요.
# - axes[0]에는 선 그래프, axes[1]에는 막대 그래프를 그리세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - axes[0].plot(), axes[1].bar() 형식으로 작성합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 30]
items = ['A', 'B', 'C']
counts = [5, 8, 6]

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 스타일 설정

# %% [markdown]
# ### 문제 20. Seaborn 스타일 설정하기 ⭐
#
# Seaborn의 스타일을 whitegrid로 설정한 뒤 막대 그래프를 그리세요.
#
# **요구사항**
# - sns.set_style('whitegrid')를 사용하세요.
# - sns.barplot()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 스타일 설정은 그래프를 그리기 전에 작성합니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'category': ['A', 'B', 'C'],
    'value': [10, 25, 15]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 21. 그래프 저장하기 ⭐⭐
#
# 선 그래프를 그리고 graph.png 파일로 저장하세요.
#
# **요구사항**
# - plt.savefig('graph.png')를 사용하세요.
# - 저장 후 그래프를 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - savefig는 show 전에 작성하는 것이 안전합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [100, 120, 140, 160]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 22. 한글 폰트 설정 코드 작성하기 ⭐⭐
#
# Matplotlib에서 한글 제목이 깨지지 않도록 기본 폰트 설정 코드를 작성하세요.
#
# **요구사항**
# - plt.rcParams를 사용하세요.
# - axes.unicode_minus도 False로 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - Windows는 Malgun Gothic, Mac은 AppleGothic을 자주 사용합니다.
#
# </details>

# %%
import matplotlib.pyplot as plt

# 여기에 한글 폰트 설정 코드를 작성하세요

x = [1, 2, 3]
y = [10, 20, 15]

plt.plot(x, y)
plt.title('한글 제목 예시')
plt.show()

# %% [markdown]
# ## Plotly 소개

# %% [markdown]
# ### 문제 23. Plotly Express로 선 그래프 그리기 ⭐⭐
#
# Plotly Express를 사용하여 월별 매출 선 그래프를 그리세요.
#
# **요구사항**
# - plotly.express를 px로 불러오세요.
# - px.line()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - Plotly Express는 인터랙티브 그래프를 쉽게 만들 수 있습니다.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'month': ['Jan', 'Feb', 'Mar', 'Apr'],
    'sales': [120, 150, 130, 180]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 24. Plotly Express로 막대 그래프 그리기 ⭐⭐
#
# Plotly Express를 사용하여 상품별 판매량 막대 그래프를 그리세요.
#
# **요구사항**
# - px.bar()를 사용하세요.
# - title을 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - px.bar(df, x='컬럼', y='컬럼') 형식입니다.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'product': ['A', 'B', 'C'],
    'sales': [50, 80, 65]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 25. Plotly hover 데이터 확인하기 ⭐⭐
#
# Plotly 산점도를 만들고 hover_data에 region 컬럼을 추가하세요.
#
# **요구사항**
# - px.scatter()를 사용하세요.
# - hover_data=['region']을 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - hover_data는 마우스를 올렸을 때 추가 정보를 보여줍니다.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'ad_cost': [100, 200, 300, 400],
    'sales': [1200, 2200, 2700, 3900],
    'region': ['Seoul', 'Busan', 'Jeju', 'Daegu']
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 종합문제

# %% [markdown]
# ### 문제 26. 매출 데이터 종합 시각화 ⭐⭐⭐
#
# 매출 데이터를 사용하여 선 그래프, 막대 그래프, boxplot을 각각 작성하세요.
#
# **요구사항**
# - 월별 매출 선 그래프를 그리세요.
# - 지역별 총 매출 막대 그래프를 그리세요.
# - 지역별 매출 분포 boxplot을 그리세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - groupby로 지역별 총 매출을 먼저 계산할 수 있습니다.
# - boxplot은 sns.boxplot()을 사용합니다.
#
# </details>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame({
    'month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar'],
    'region': ['Seoul', 'Busan', 'Seoul', 'Busan', 'Seoul', 'Busan'],
    'sales': [120, 100, 150, 130, 170, 140]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 27. 상관관계와 산점도 함께 확인하기 ⭐⭐⭐
#
# 광고비, 방문자수, 매출 데이터의 상관관계를 heatmap으로 확인하고, 광고비와 매출의 산점도를 그리세요.
#
# **요구사항**
# - df.corr()를 사용하세요.
# - sns.heatmap()을 사용하세요.
# - sns.scatterplot()을 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 상관관계 전체는 heatmap, 특정 변수 관계는 scatterplot으로 확인합니다.
#
# </details>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'ad_cost': [100, 150, 200, 250, 300],
    'visitors': [1000, 1200, 1500, 1700, 2000],
    'sales': [1200, 1600, 2100, 2600, 3100]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ## 심화: Plotly Dashboard

# %% [markdown]
# ### 문제 28. Plotly subplot으로 대시보드 형태 만들기 ⭐⭐⭐
#
# Plotly의 make_subplots를 사용하여 선 그래프와 막대 그래프를 하나의 화면에 배치하세요.
#
# **요구사항**
# - plotly.subplots의 make_subplots를 사용하세요.
# - go.Scatter와 go.Bar를 사용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - fig.add_trace()로 각 위치에 그래프를 추가합니다.
#
# </details>

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

months = ['Jan', 'Feb', 'Mar']
sales = [100, 150, 130]
products = ['A', 'B', 'C']
counts = [20, 35, 25]

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 29. Plotly 그래프를 HTML로 저장하기 ⭐⭐
#
# Plotly 그래프를 interactive_chart.html 파일로 저장하세요.
#
# **요구사항**
# - fig.write_html()을 사용하세요.
# - 저장 후 fig.show()로 그래프를 출력하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - Plotly 그래프는 HTML 파일로 저장할 수 있습니다.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'month': ['Jan', 'Feb', 'Mar'],
    'sales': [100, 150, 130]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 30. Plotly facet으로 그룹별 그래프 만들기 ⭐⭐⭐
#
# 지역별 월 매출을 facet_col을 사용하여 지역별 그래프로 나누어 표현하세요.
#
# **요구사항**
# - px.line()을 사용하세요.
# - facet_col='region'을 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - facet_col은 범주별로 그래프를 나누어 보여줍니다.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'month': ['Jan', 'Feb', 'Mar', 'Jan', 'Feb', 'Mar'],
    'region': ['Seoul', 'Seoul', 'Seoul', 'Busan', 'Busan', 'Busan'],
    'sales': [100, 130, 160, 90, 120, 140]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 31. Plotly 색상 그룹 지정하기 ⭐⭐
#
# 지역별 매출 추이를 하나의 Plotly 선 그래프에 그리고 color 옵션으로 지역을 구분하세요.
#
# **요구사항**
# - px.line()을 사용하세요.
# - color='region'을 설정하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - color 옵션은 Matplotlib/Seaborn의 hue와 비슷한 역할을 합니다.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'month': ['Jan', 'Feb', 'Mar', 'Jan', 'Feb', 'Mar'],
    'region': ['Seoul', 'Seoul', 'Seoul', 'Busan', 'Busan', 'Busan'],
    'sales': [100, 130, 160, 90, 120, 140]
})

# 여기에 코드를 작성하세요

# %% [markdown]
# ### 문제 32. 간단한 대시보드형 종합 시각화 ⭐⭐⭐
#
# Plotly를 사용하여 매출 추이 그래프와 지역별 매출 막대 그래프를 만들고 각각 출력하세요.
#
# **요구사항**
# - px.line()으로 월별 매출 추이를 그리세요.
# - px.bar()로 지역별 총 매출을 그리세요.
# - groupby를 활용하세요.
#
# <details>
# <summary>힌트 보기</summary>
#
# - 먼저 월별 총 매출과 지역별 총 매출을 groupby로 계산하세요.
#
# </details>

# %%
import pandas as pd
import plotly.express as px

df = pd.DataFrame({
    'month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar'],
    'region': ['Seoul', 'Busan', 'Seoul', 'Busan', 'Seoul', 'Busan'],
    'sales': [100, 90, 130, 120, 160, 140]
})

# 여기에 코드를 작성하세요
